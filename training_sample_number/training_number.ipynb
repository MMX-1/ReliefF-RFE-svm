# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import matplotlib.ticker
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

#% matplotlib inline
font1={'family': 'Times New Roman', 'weight': 'light', 'size':17}#设置字体模板
font2={'family': 'Times New Roman', 'weight': 'bold', 'size': 16}#设置字体模板
fig = plt.figure(figsize=(18,18),facecolor="snow")
#fig.suptitle("Controlling spacing around and between subplots")

gs=GridSpec(12,12)
ax1=fig.add_subplot(gs[0:5, 0:5],facecolor="whitesmoke")
ax2=fig.add_subplot(gs[0:5, 6:11],facecolor="whitesmoke")
ax3=fig.add_subplot(gs[6:11,0:5],facecolor="whitesmoke")
ax4=fig.add_subplot(gs[6:11,6:11],facecolor="whitesmoke")

sample_num=[200,400,600,800,1000,1200,1400,1600,1800,2000]
# linear_svm_accuracy
linear_kernel_svm_accuracy=np.array(pd.read_csv("linear_kernel_svm_accuracy.csv"))

baiyun_linear_accuracy=linear_kernel_svm_accuracy[0,1:]
guizhou_linear_accuracy=linear_kernel_svm_accuracy[1,1:]
jinhui_linear_accuracy=linear_kernel_svm_accuracy[2,1:]
jinshi_linear_accuracy=linear_kernel_svm_accuracy[3,1:]
laobai_linear_accuracy=linear_kernel_svm_accuracy[4,1:]
shanxi_linear_accuracy=linear_kernel_svm_accuracy[5,1:]
tongren_linear_accuracy=linear_kernel_svm_accuracy[6,1:]
weiwei_linear_accuracy=linear_kernel_svm_accuracy[7,1:]
yanghe_linear_accuracy=linear_kernel_svm_accuracy[8,1:]
ax1.plot(sample_num, baiyun_linear_accuracy, "h-", color="skyblue", label=r"Proposed Method for stock data 600332 ", lw=1.5)
ax1.plot(sample_num, guizhou_linear_accuracy, "v-", color="green", label=r"Proposed Method for stock data 600519", lw=1.5)
ax1.plot(sample_num, jinhui_linear_accuracy, "x-", color="gray", label=r"Proposed Method for stock data 603919", lw=1.5)
ax1.plot(sample_num, jinshi_linear_accuracy, "P-", color="cyan", label=r"Proposed Method for stock data 603369", lw=1.5)
ax1.plot(sample_num, laobai_linear_accuracy, "*-", color="magenta", label=r"Proposed Method for stock data 600559", lw=1.5)
ax1.plot(sample_num, shanxi_linear_accuracy, "1-", color="yellow", label=r"Proposed Method for stock data 600809", lw=1.5)
ax1.plot(sample_num, tongren_linear_accuracy, "^-", color="pink", label=r"Proposed Method for stock data 600085", lw=1.5)
ax1.plot(sample_num, weiwei_linear_accuracy, "|-", color="peru", label=r"Proposed Method for stock data 600300", lw=1.5)
ax1.plot(sample_num, yanghe_linear_accuracy, "--", color="blue", label=r"Proposed Method for stock data 002304", lw=1.5)

#ax1.set_xlabel('')
#ax1.set_xticklabels([])
ax1.set_xlabel("Training Sample Number",fontsize=15)
ax1.set_title("Accuracy of linear kernel SVM-RFE with ReliefF",fontsize=15)
ax1.set_ylabel('Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax1.xaxis.grid(True, which='major')
ax1.yaxis.grid(True, which='major')
#ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(2.1))
ax1.legend(bbox_to_anchor=(3.3,-1.3),scatterpoints=1,prop=font1,shadow=True,frameon=False,ncol=5)#添加图例，
ax1.ticklabel_format(axis='both',style='sci')#sci文章的风格
ax1.tick_params(labelsize=15)

# linear_svm_F_measure
linear_kernel_svm_F_measure=np.array(pd.read_csv("linear_kernel_svm_F_measure.csv"))

baiyun_linear_F_measure=linear_kernel_svm_F_measure[0,1:]
guizhou_linear_F_measure=linear_kernel_svm_F_measure[1,1:]
jinhui_linear_F_measure=linear_kernel_svm_F_measure[2,1:]
jinshi_linear_F_measure=linear_kernel_svm_F_measure[3,1:]
laobai_linear_F_measure=linear_kernel_svm_F_measure[4,1:]
shanxi_linear_F_measure=linear_kernel_svm_F_measure[5,1:]
tongren_linear_F_measure=linear_kernel_svm_F_measure[6,1:]
weiwei_linear_F_measure=linear_kernel_svm_F_measure[7,1:]
yanghe_linear_F_measure=linear_kernel_svm_F_measure[8,1:]
ax2.plot(sample_num, baiyun_linear_F_measure, "h-", color="skyblue", label=r"Proposed Method for stock data 600332 ", lw=1.5)
ax2.plot(sample_num, guizhou_linear_F_measure, "v-", color="green", label=r"Proposed Method for stock data 600519", lw=1.5)
ax2.plot(sample_num, jinhui_linear_F_measure, "x-", color="gray", label=r"Proposed Method for stock data 603919", lw=1.5)
ax2.plot(sample_num, jinshi_linear_F_measure, "P-", color="cyan", label=r"Proposed Method for stock data 603369", lw=1.5)
ax2.plot(sample_num, laobai_linear_F_measure, "*-", color="magenta", label=r"Proposed Method for stock data 600559", lw=1.5)
ax2.plot(sample_num, shanxi_linear_F_measure, "1-", color="yellow", label=r"Proposed Method for stock data 600809", lw=1.5)
ax2.plot(sample_num, tongren_linear_F_measure, "^-", color="pink", label=r"Proposed Method for stock data 600085", lw=1.5)
ax2.plot(sample_num, weiwei_linear_F_measure, "|-", color="peru", label=r"Proposed Method for stock data 600300", lw=1.5)
ax2.plot(sample_num, yanghe_linear_F_measure, "--", color="blue", label=r"Proposed Method for stock data 002304", lw=1.5)

#ax1.set_xlabel('')
#ax1.set_xticklabels([])
ax2.set_xlabel("Training Sample Number",fontsize=15)
ax2.set_title("F-test of linear kernel SVM-RFE with ReliefF",fontsize=15)
ax2.set_ylabel('F-test',fontsize=15)
#ax1.set_xticks(feature_num)
ax2.xaxis.grid(True, which='major')
ax2.yaxis.grid(True, which='major')
#ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(2.1))
#ax2.legend(bbox_to_anchor=(3.3,-1.3),scatterpoints=1,prop=font1,shadow=True,frameon=False,ncol=5)#添加图例，
ax2.ticklabel_format(axis='both',style='sci')#sci文章的风格
ax2.tick_params(labelsize=15)



# gaussian_kernel_svm_accuracy
Gaussian_kernel_svm_accuracy=np.array(pd.read_csv("Gaussian_kernel_svm_accuracy.csv"))

baiyun_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[0,1:]
guizhou_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[1,1:]
jinhui_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[2,1:]
jinshi_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[3,1:]
laobai_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[4,1:]
shanxi_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[5,1:]
tongren_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[6,1:]
weiwei_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[7,1:]
yanghe_Gaussian_accuracy=Gaussian_kernel_svm_accuracy[8,1:]
ax3.plot(sample_num, baiyun_Gaussian_accuracy, "h-", color="skyblue", label=r"Proposed Method for stock data 600332 ", lw=1.5)
ax3.plot(sample_num, guizhou_Gaussian_accuracy, "v-", color="green", label=r"Proposed Method for stock data 600519", lw=1.5)
ax3.plot(sample_num, jinhui_Gaussian_accuracy, "x-", color="gray", label=r"Proposed Method for stock data 603919", lw=1.5)
ax3.plot(sample_num, jinshi_Gaussian_accuracy, "P-", color="cyan", label=r"Proposed Method for stock data 603369", lw=1.5)
ax3.plot(sample_num, laobai_Gaussian_accuracy, "*-", color="magenta", label=r"Proposed Method for stock data 600559", lw=1.5)
ax3.plot(sample_num, shanxi_Gaussian_accuracy, "1-", color="yellow", label=r"Proposed Method for stock data 600809", lw=1.5)
ax3.plot(sample_num, tongren_Gaussian_accuracy, "^-", color="pink", label=r"Proposed Method for stock data 600085", lw=1.5)
ax3.plot(sample_num, weiwei_Gaussian_accuracy, "|-", color="peru", label=r"Proposed Method for stock data 600300", lw=1.5)
ax3.plot(sample_num, yanghe_Gaussian_accuracy, "--", color="blue", label=r"Proposed Method for stock data 002304", lw=1.5)

#ax1.set_xlabel('')
#ax1.set_xticklabels([])
ax3.set_xlabel("Training Sample Number",fontsize=15)
ax3.set_title("Accuracy of Gaussian kernel SVM-RFE with ReliefF",fontsize=15)
ax3.set_ylabel('Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax3.xaxis.grid(True, which='major')
ax3.yaxis.grid(True, which='major')
#ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(2.1))
#ax3.legend(bbox_to_anchor=(3.3,-1.3),scatterpoints=1,prop=font1,shadow=True,frameon=False,ncol=5)#添加图例，
ax3.ticklabel_format(axis='both',style='sci')#sci文章的风格
ax3.tick_params(labelsize=15)



# gaussian_kernel_svm_F_measure
Gaussian_kernel_svm_F_measure=np.array(pd.read_csv("Gaussian_kernel_svm_F_measure.csv"))

baiyun_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[0,1:]
guizhou_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[1,1:]
jinhui_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[2,1:]
jinshi_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[3,1:]
laobai_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[4,1:]
shanxi_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[5,1:]
tongren_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[6,1:]
weiwei_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[7,1:]
yanghe_Gaussian_F_measure=Gaussian_kernel_svm_F_measure[8,1:]
ax4.plot(sample_num, baiyun_Gaussian_F_measure, "h-", color="skyblue", label=r"Proposed Method for stock data 600332 ", lw=1.5)
ax4.plot(sample_num, guizhou_Gaussian_F_measure, "v-", color="green", label=r"Proposed Method for stock data 600519", lw=1.5)
ax4.plot(sample_num, jinhui_Gaussian_F_measure, "x-", color="gray", label=r"Proposed Method for stock data 603919", lw=1.5)
ax4.plot(sample_num, jinshi_Gaussian_F_measure, "P-", color="cyan", label=r"Proposed Method for stock data 603369", lw=1.5)
ax4.plot(sample_num, laobai_Gaussian_F_measure, "*-", color="magenta", label=r"Proposed Method for stock data 600559", lw=1.5)
ax4.plot(sample_num, shanxi_Gaussian_F_measure, "1-", color="yellow", label=r"Proposed Method for stock data 600809", lw=1.5)
ax4.plot(sample_num, tongren_Gaussian_F_measure, "^-", color="pink", label=r"Proposed Method for stock data 600085", lw=1.5)
ax4.plot(sample_num, weiwei_Gaussian_F_measure, "|-", color="peru", label=r"Proposed Method for stock data 600300", lw=1.5)
ax4.plot(sample_num, yanghe_Gaussian_F_measure, "--", color="blue", label=r"Proposed Method for stock data 002304", lw=1.5)

#ax1.set_xlabel('')
#ax1.set_xticklabels([])
ax4.set_xlabel("Training Sample Number",fontsize=15)
ax4.set_title("F-test of Gaussian kernel SVM-RFE with ReliefF",fontsize=15)
ax4.set_ylabel('F-test',fontsize=15)
#ax1.set_xticks(feature_num)
ax4.xaxis.grid(True, which='major')
ax4.yaxis.grid(True, which='major')
#ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(2.1))
#ax3.legend(bbox_to_anchor=(3.3,-1.3),scatterpoints=1,prop=font1,shadow=True,frameon=False,ncol=5)#添加图例，
ax4.ticklabel_format(axis='both',style='sci')#sci文章的风格
ax4.tick_params(labelsize=15)

plt.savefig("number_training.eps",format='eps',dpi=1000, bbox_inches='tight')
