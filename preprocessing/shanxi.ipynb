# %%
import pandas as pd
import numpy as np
shanxi_data=pd.read_csv('shanxi_600809.csv')
shanxi_arr=np.array(shanxi_data)

# %%
#检查有无字符数
for i in range(0,51):
    print(i,shanxi_arr[:,i])
# Out:
# 0 ['2025/1/3' '2025/1/2' '2024/12/31' ... '2016/4/6' '2016/4/5' '2016/4/1']
# 1 [178.0 183.25 185.5 ... 18.15 18.02 18.21]
# 2 [178.0 177.98 184.21 ... 18.4 18.22 18.18]
# 3 [1.0369 1.9156 1.3837 ... 1.4416 0.6634 0.3677]
# 4 ['5,701,740.53' '8,994,051.90' '6,216,669.65' ... '8,319,467.07'
#  '5,434,345.01' '3,459,177.28']
# 5 ['6,001,260.80' '5,470,363.00' '4,659,437.20' ... '6,230,432.60'
#  '5,830,516.20' '8,218,998.20']
# 6 ['194,083.74' '241,394.64' '-28,362.79' ... '-30,193.96' '-158,541.54'
#  '-60,248.88']
# 7 [-14.5403 -15.7295 -15.5326 ... 26.3498 26.7597 25.8905]
# 8 ['1,610,993.33' '1,611,359.90' '1,017,962.96' ... '4,074,060.85'
#  '4,101,963.57' '4,120,817.46']
# 9 [58.0396 64.2505 77.0976 ... 203.861 175.3002 169.1466]
# 10 [25.0 25.0 25.0 ... 66.6667 66.6667 66.6667]
# 11 [61.0388 60.0355 72.4816 ... 261.4516 219.4175 212.753]
# 12 [85.9949 88.4071 104.5809 ... 190.4059 163.1148 159.9049]
# 13 [89.2084 89.5557 105.4812 ... 166.3366 145.5357 155.303]
# 14 [606.6 605.6 611.83 ... 200.76 200.13 199.92]
# 15 ['-153,612.78' '-250,194.31' '-328,732.20' ... '172,604.43' '113,409.10'
#  '-36,063.47']
# 16 ['178,085,228.14' '178,084,590.73' '178,386,458.80' ... '122,909,934.49'
#  '122,826,898.70' '122,814,902.31']
# 17 ['-34,058,637.23' '-32,813,663.39' '-27,953,449.63' ... '33,867,784.87'
#  '35,197,278.55' '31,859,456.82']
# 18 [186.4029 188.1457 190.0333 ... 17.8039 17.7141 17.6275]
# 19 [182.782 184.968 187.148 ... 18.296 18.178 18.122]
# 20 [181.9418 183.9126 186.879 ... 18.2005 18.1008 18.0412]
# 21 [-2.8447 -2.6639 -2.0305 ... 0.2767 0.3069 0.3547]
# 22 [-10.88 -11.54 -4.19 ... 0.46 0.77 0.98]
# 23 [-3.8719 -3.5747 -3.2732 ... 4.8571 4.8769 4.5515]
# 24 [-0.4301 -0.3996 -0.3719 ... 0.5305 0.5024 0.4681]
# 25 [-5.0911 -5.827 -3.2519 ... 3.6961 3.4688 4.1834]
# 26 [-176.5584 -172.9396 -105.4629 ... 74.965 81.5602 98.013]
# 27 [-0.003 -0.0025 -0.0017 ... 0.0034 0.0035 0.0032]
# 28 [-8.8518 -10.4364 -5.7836 ... 0.5855 0.5355 0.6264]
# 29 [5.4676 5.1526 4.9746 ... 78.5194 76.0338 76.5507]
# 30 [6.3193 6.7451 7.5414 ... 77.4041 76.8465 77.2529]
# 31 [3.7642 1.9676 -0.1591 ... 80.7499 74.4083 75.1462]
# 32 [8.9686 8.8195 15.345 ... 76.484 72.7133 71.8782]
# 33 [-1.0 -1.0 -0.9173 ... 0.1377 0.7133 1.189]
# 34 [21.8091 17.2605 -44.1626 ... 42.7663 103.3305 101.9306]
# 35 [49.2842 68.1157 56.2544 ... 55.1099 47.2529 41.4996]
# 36 [95.6522 96.8057 99.5753 ... 12.6812 18.5965 20.0]
# 37 [-0.3876 -0.3874 -0.283 ... 0.9031 0.909 0.9186]
# 38 [179.24 185.13 186.535 ... 18.1875 18.1975 18.2725]
# 39 [0.5714 0.7143 0.7143 ... 0.5714 0.5714 0.4286]
# 40 [0.2 0.2222 0.2222 ... 0.6667 0.6667 0.7143]
# 41 [0.5 0.5455 0.5455 ... 0.2143 0.2857 0.2857]
# 42 [-10.7286 -10.1285 -9.512 ... 1.1135 1.0675 0.9909]
# 43 [-0.2602 -0.2317 -0.2069 ... 0.0399 0.0381 0.0355]
# 44 [92.3476 89.4282 93.9847 ... 113.0221 115.9033 116.9132]
# 45 [0.8099 0.7957 0.7803 ... -0.0462 -0.044 -0.0411]
# 46 [-0.0753 -0.0789 -0.0563 ... 0.0804 0.0582 0.0666]
# 47 [3.9329 4.4371 4.4464 ... 0.6036 0.5786 0.5864]
# 48 [-19.5712 -22.2037 -38.8951 ... 16.3375 16.0836 18.0865]
# 49 [22.2106 22.1408 22.137 ... 25.5953 25.7948 25.9493]
# 50 [8.2355 7.6098 6.7504 ... 0.9356 0.9546 0.9246]

# %%
#处理字符串
a=shanxi_arr[:,17]
num=len(a)
b=[]
flo=[]
#处理逗号
for i in range(num):
    
    b.append(a[i].replace(",",""))
    #print(str2float(i))
#str转换浮点数
for i in range(num):
    flo.append(float(b[i]))
#保存数据
for i in range(num):
    shanxi_arr[i,17]=flo[i]

# %%
#股票数量
stock_num=len(shanxi_arr[:,1])
#目标变量
open_price_today=shanxi_arr[:stock_num-1,1]#当日开盘价
open_price_yest=shanxi_arr[1:stock_num,1]#昨日开盘价
list_=list(open_price_today-open_price_yest)
target=[]
#target
for i in list_:
    if i>=0:
        target.append(1)
    else:
        target.append(-1)
target=np.array(target)

# %%
#标准化数据
fea=shanxi_arr[1:,3:]
mean=np.mean(np.array(fea),axis=0,keepdims=True)
num_samp=fea.shape[0]
fea_num=fea.shape[1]
mean,fea,fea_num,num_samp
# Out:
# (array([[1.0371852512916853, 6502597.205758573, 6527215.652231105,
#          77.66189915453013, -2.1266832315641175, 2273831.2257914543,
#          122.1316727101923, 49.02145115077505, 124.06093532174735,
#          124.38204105213718, 109.7962980272431, 454.1303053076556,
#          3491.0871100047, 160412495.1981911, 10914239.16040394,
#          161.6025173790508, 161.86932080789052, 161.8682210427425,
#          -0.009293987787693705, 0.5059229685298263, 0.6475746829497415,
#          0.1214561296383278, 0.7132351338656644, 12.520032268670759,
#          1.20713950211367e-05, 0.41835692813527564, 51.93413071864721,
#          51.99597472992018, 51.81044368248002, 52.415106341005206,
#          1.0943279473931427, 17.732678628464047, 49.599741052137084,
#          47.3591677782997, 0.3624417097228743, 161.89764091122618,
#          0.6328852982620928, 0.35016876467825264, 0.3482672146547659,
#          1.043999342414277, -0.0010489431658055385, 108.44185241897603,
#          -0.006836965711601465, 0.0101924847346172, 6.706900563644894,
#          4.536456505401604, 25.21896002818225, 9.023807515265382,
#          0.36418961953968954]], dtype=object),
#  array([[1.9156, 8994051.9, 5470363.0, ..., 22.1408, 7.6098, 0.5113],
#         [1.3837, 6216669.65, 4659437.2, ..., 22.137, 6.7504, 0.3939],
#         [1.007, 4797135.0, 4448460.8, ..., 22.2347, 6.2579, 0.3687],
#         ...,
#         [1.4416, 8319467.07, 6230432.6, ..., 25.5953, 0.9356, 0.4284],
#         [0.6634, 5434345.01, 5830516.2, ..., 25.7948, 0.9546, 0.3772],
#         [0.3677, 3459177.28, 8218998.2, ..., 25.9493, 0.9246, 0.3772]],
#        dtype=object),
#  49,
#  2129)

# %%
#求方差
squa_s=np.sum((fea-mean)**2,axis=0)/(num_samp-1)#方差
std=[]
for i in range(fea_num):
    std.append(np.sqrt(squa_s[i]))

# %%
#特征标准化
stan_s=np.array(std).reshape(1,fea_num)
norm_fea=(fea-mean)/stan_s
norm_fea
# Out:
# array([[1.8890916535507414, 0.7630839461633936, -0.42325056536080674,
#         ..., -2.4577792261159357, -0.14709752144034452,
#         1.4450255653691872],
#        [0.7452039262542879, -0.08757402977040135, -0.7480118294699406,
#         ..., -2.4608133637090845, -0.23649988214993828,
#         0.29183704907606184],
#        [-0.06491547000924668, -0.5223497874598185, -0.8325041003548902,
#         ..., -2.3828040892746665, -0.28773407187471706,
#         0.04430425000803204],
#        ...,
#        [0.8697218796486567, 0.5564717788668526, -0.11885629882381447,
#         ..., 0.3004913832361564, -0.8414066159806872, 0.6307212382763417],
#        [-0.8038510276310953, -0.32718479807049233, -0.2790156569327486,
#         ..., 0.4597836068765481, -0.839430068559833, 0.12779745604288306],
#        [-1.4397743232911089, -0.9321401236586603, 0.6775286207581481,
#         ..., 0.583145253755953, -0.8425509329085504, 0.12779745604288306]],
#       dtype=object)

# %%
X_y=np.c_[norm_fea,target]#将X和target合并
#导出数据
data_1=pd.DataFrame(X_y)
data_1.to_csv(r'norm_shanxi.csv')
