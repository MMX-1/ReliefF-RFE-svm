# %%
import pandas as pd
import numpy as np
wuliangye_data=pd.read_csv('wuliangye_000858.csv')
wuliangye_arr=np.array(wuliangye_data)

# %%
#检查有无字符数
for i in range(0,51):
    print(i,wuliangye_arr[:,i])
# Out:
# 0 ['2025/1/3' '2025/1/2' '2024/12/31' ... '2016/4/6' '2016/4/5' '2016/4/1']
# 1 [137.08 140.0 141.22 ... 28.01 27.88 28.0]
# 2 [135.4 136.99 140.04 ... 28.59 28.08 27.99]
# 3 [0.9307 1.7175 1.9087 ... 1.1099 0.8675 0.5879]
# 4 ['16,955,818.11' '25,679,866.97' '24,799,741.03' ... '28,359,661.65'
#  '27,163,692.09' '20,037,132.60']
# 5 ['19,344,371.00' '18,075,133.20' '14,884,976.60' ... '26,005,384.60'
#  '25,738,140.80' '31,396,178.60']
# 6 ['878,148.25' '1,123,092.47' '564,428.08' ... '-1,238,654.07'
#  '-1,382,349.72' '-1,398,423.10']
# 7 [-19.2316 -20.5641 -18.0346 ... 10.8586 15.0568 14.9344]
# 8 ['5,264,806.56' '5,270,874.89' '4,198,879.20' ... '10,693,048.63'
#  '10,725,169.31' '13,495,606.34']
# 9 [69.6757 81.0371 96.4724 ... 268.3437 220.1053 214.9446]
# 10 [25.0 33.3333 33.3333 ... 66.6667 66.6667 66.6667]
# 11 [76.6605 89.2764 106.4222 ... 449.5154 381.1183 370.6401]
# 12 [95.0 104.6431 123.2997 ... 239.9061 198.3936 198.6877]
# 13 [97.2441 105.6365 121.1605 ... 219.2475 184.2965 192.4051]
# 14 [189.72 192.28 195.33 ... -48.05 -48.64 -48.94]
# 15 ['-743,484.86' '-784,538.71' '-1,232,806.24' ... '620,795.04' '400,688.64'
#  '233,054.12']
# 16 ['531,949,795.71' '532,145,055.16' '532,701,842.09' ... '349,823,447.97'
#  '349,304,620.17' '349,217,042.28']
# 17 ['-110,773,825.56' '-92,465,733.29' '-77,714,630.50' ... '210,194,928.42'
#  '209,893,833.01' '202,039,900.89']
# 18 [140.8134 141.9338 142.8964 ... 27.5677 27.4054 27.2657]
# 19 [139.232 140.65 141.868 ... 28.178 28.06 28.06]
# 20 [138.5072 140.0608 141.5962 ... 28.1547 27.937 27.8656]
# 21 [-1.7515 -1.4004 -1.0105 ... 0.2836 0.2945 0.3675]
# 22 [-7.68 -6.49 -2.41 ... 0.51 0.83 1.29]
# 23 [-1.9842 -1.7326 -1.4922 ... 4.9186 5.0595 4.9648]
# 24 [-0.2147 -0.1871 -0.1663 ... 0.6219 0.6099 0.5967]
# 25 [-4.4022 -3.8166 -2.1104 ... 3.9227 2.8446 3.3286]
# 26 [-230.3123 -215.1174 -99.3129 ... 92.1336 74.7736 82.1123]
# 27 [-0.0022 -0.0017 -0.0011 ... 0.0025 0.0025 0.0027]
# 28 [-5.9109 -5.2118 -2.88 ... 0.9782 0.6673 0.7573]
# 29 [7.5864 7.8432 7.542 ... 84.1708 78.6278 79.1357]
# 30 [9.2386 10.0646 11.1754 ... 81.274 79.8255 80.4244]
# 31 [4.2822 3.4003 0.2754 ... 89.9646 76.2324 76.5584]
# 32 [10.1635 12.6095 20.4933 ... 87.3082 81.2692 79.86]
# 33 [-0.9128 -0.9113 -0.7 ... 2.283 1.9434 2.566]
# 34 ['5.4782' '-3.4465' '-13.7245' ... '-32.1985' '53.5679' '55.8744']
# 35 [47.3391 68.3265 66.8661 ... 49.1874 47.923 41.3869]
# 36 [95.1091 95.2017 99.7498 ... 3.2967 15.9151 18.3024]
# 37 [-0.2034 0.0205 0.3847 ... 0.8581 0.8652 0.8857]
# 38 [137.57 140.9225 141.6475 ... 28.035 27.96 28.1675]
# 39 [0.5714 0.5714 0.4286 ... 0.7143 0.7143 0.5714]
# 40 [0.1 0.1111 0.1111 ... 0.6667 0.6667 0.7143]
# 41 [0.5 0.4545 0.4545 ... 0.2143 0.2857 0.2857]
# 42 [-4.1771 -3.6941 -3.339 ... 1.8961 1.8421 1.775]
# 43 [-0.1277 -0.1097 -0.0949 ... 0.0341 0.0335 0.0324]
# 44 [92.4485 92.2305 96.2871 ... 114.7732 117.2932 118.6017]
# 45 [0.8615 0.8564 0.8499 ... -0.3887 -0.4029 -0.4166]
# 46 [-0.0545 -0.0457 -0.0355 ... 0.0787 0.0573 0.0568]
# 47 [2.3414 2.385 2.37 ... 0.76 0.7657 0.8021]
# 48 [-3.8312 -19.3132 -34.4552 ... -25.1129 -27.9776 -22.2932]
# 49 [22.2851 22.1154 22.0407 ... 25.3374 25.6439 25.988]
# 50 [3.6151 3.1399 2.6957 ... 1.5081 1.5896 1.5981]

# %%
#处理字符串
a=wuliangye_arr[:,34]
num=len(a)
b=[]
flo=[]
#处理逗号
for i in range(num):
    
    b.append(a[i].replace(",",""))
    #print(str2float(i))
#str转换浮点数
for i in range(num):
    flo.append(float(b[i]))
#保存数据
for i in range(num):
    wuliangye_arr[i,34]=flo[i]

# %%
#股票数量
stock_num=len(wuliangye_arr[:,1])
#目标变量
open_price_today=wuliangye_arr[:stock_num-1,1]#当日开盘价
open_price_yest=wuliangye_arr[1:stock_num,1]#昨日开盘价
list_=list(open_price_today-open_price_yest)
target=[]
#target
for i in list_:
    if i>=0:
        target.append(1)
    else:
        target.append(-1)
target=np.array(target)

# %%
#标准化数据
fea=wuliangye_arr[1:,3:]
mean=np.mean(np.array(fea),axis=0,keepdims=True)
num_samp=fea.shape[0]
fea_num=fea.shape[1]
mean,fea,fea_num,num_samp
# Out:
# (array([[1.0325703616721469, 24609165.840699855, 24639176.14222641,
#          -10646.751833724753, -2.217483278534521, 8012283.475349924,
#          125.09073781117914, 48.907937247534036, 123.39649483325513,
#          119.65329727571638, 112.0550656646313, 125.55839361202459,
#          -19257.581446688586, 455759947.2274868, 33526117.732855856,
#          134.95047534053552, 135.1229084077029, 135.12192752465933,
#          -0.0074596993893847, 0.31943165805542556, 0.4364728511038043,
#          0.08351977454203853, 0.4656232033818688, 8.456721042743062,
#          -4.368248003757621e-06, 0.2666113198684828, 51.06275481446685,
#          51.12945603569756, 50.92935035227801, 51.60305157350872,
#          1.1279675904180375, 15.267318036636915, 49.57081972757158,
#          48.60375270079852, 0.3473802724283693, 135.15166744950665,
#          0.6762309065288886, 0.2674439173320807, 0.3218457491780166,
#          0.6791851103804593, -0.0005846406763738903, 106.02513020197276,
#          -0.0038540629403475625, 0.0065139971817754815, 4.428317144199163,
#          3.589284077031469, 25.163125927665572, 6.263240864255512,
#          0.3523350868952561]], dtype=object),
#  array([[1.7175, 25679866.97, 18075133.2, ..., 22.1154, 3.1399, 0.3756],
#         [1.9087, 24799741.03, 14884976.6, ..., 22.0407, 2.6957, 0.287],
#         [1.3172, 16434071.5, 12847207.0, ..., 22.0969, 2.5021, 0.2654],
#         ...,
#         [1.1099, 28359661.65, 26005384.6, ..., 25.3374, 1.5081, 0.6274],
#         [0.8675, 27163692.09, 25738140.8, ..., 25.6439, 1.5896, 0.5458],
#         [0.5879, 20037132.6, 31396178.6, ..., 25.988, 1.5981, 0.5406]],
#        dtype=object),
#  49,
#  2129)

# %%
#求方差
squa_s=np.sum((fea-mean)**2,axis=0)/(num_samp-1)#方差
std=[]
for i in range(fea_num):
    std.append(np.sqrt(squa_s[i]))

# %%
#特征标准化
stan_s=np.array(std).reshape(1,fea_num)
norm_fea=(fea-mean)/stan_s
norm_fea
# Out:
# array([[1.6013476052394315, 0.08938082553006617, -0.6974301923278142,
#         ..., -2.285524613139536, -0.6399717224600069, 0.2321027985473943],
#        [2.0483682114279205, 0.015908984570072962, -1.0363846371229597,
#         ..., -2.3415429995212453, -0.7309881857509887, -0.65181659795815],
#        [0.6654566603793263, -0.682446913486997, -1.2528978526147714, ...,
#         -2.299397975228714, -0.7706567748845639, -0.8673093627947156],
#        ...,
#        [0.1807946746948407, 0.31308681984992043, 0.14515977970456997,
#         ..., 0.1306901247703331, -0.9743271137212047, 2.7441897515958815],
#        [-0.38593019423868286, 0.21324873837567918, 0.11676510031674771,
#         ..., 0.3605379885721254, -0.9576277851344982, 1.93010597332441],
#        [-1.0396276915728957, -0.381667763507235, 0.7179321593661206, ...,
#         0.6185825234308432, -0.9558861373677866, 1.8782280854933848]],
#       dtype=object)

# %%
X_y=np.c_[norm_fea,target]#将X和target合并
#导出数据
data_1=pd.DataFrame(X_y)
data_1.to_csv(r'norm_wuliangye.csv')
