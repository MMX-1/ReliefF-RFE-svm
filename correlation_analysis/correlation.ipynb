# %%
import pandas as pd
jinhui=pd.read_csv("norm_jinhuijiu.csv")
jin_cor=jinhui[170:].corr()
jinshiyuan=pd.read_csv("norm_jinshi.csv")
jinshiyuan_cor=jinshiyuan[170:].corr()
laobai=pd.read_csv("norm_laobai.csv")
laobai_cor=laobai[170:].corr()
weiwei=pd.read_csv("norm_weiwei.csv")
weiwei_cor=weiwei[170:].corr()
tongren=pd.read_csv("norm_tongren.csv")
tongren_cor=tongren[170:].corr()
baiyunshan=pd.read_csv("norm_baiyunshan.csv")
baiyunshan_cor=baiyunshan[170:].corr()
guizhou=pd.read_csv("norm_guizhou.csv")
guizhou_cor=guizhou[170:].corr()
shanxi=pd.read_csv("norm_shanxi.csv")
shanxi_cor=shanxi[170:].corr()
yanghe=pd.read_csv("norm_yanghe.csv")
yanghe_cor=yanghe[170:].corr()

# %%
shanxi_cor.BR
# Out:
# QRR        -0.002064
# TAPI        0.118859
# VMA         0.158346
# VMACD       0.039854
# VOSC        0.105487
# VSTD        0.072414
# CR          0.947514
# PSY         0.454692
# VR          0.763000
# AR          0.799546
# BR          1.000000
# WAD        -0.125917
# MOBV        0.096671
# PVT        -0.040762
# WVAD        0.668039
# BBI        -0.095757
# MA         -0.075445
# EXPMA      -0.075317
# MACD        0.279075
# MTM         0.324746
# PRICEOSC    0.756378
# TRIX        0.795712
# BIAS        0.537675
# CCI         0.519810
# DBCD        0.644082
# DPO         0.373631
# K           0.520983
# D           0.592028
# J           0.339479
# RSI         0.606373
# SRDM        0.374428
# VROC        0.061036
# VRSI        0.018660
# WR         -0.527726
# ADTM        0.690994
# CDP        -0.069246
# DPTB       -0.035615
# JDQS        0.453951
# JDRS       -0.320510
# MI          0.544704
# MICD        0.227381
# RC          0.629081
# RCCD        0.024309
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#% matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
#% matplotlib inline



fig = plt.figure(figsize=(20,20),facecolor="snow")

gs=GridSpec(12,12)
ax1=fig.add_subplot(gs[0:3, 0:3],facecolor="whitesmoke")
ax2=fig.add_subplot(gs[0:3, 4:7],facecolor="whitesmoke")
ax3=fig.add_subplot(gs[0:3,8:11],facecolor="whitesmoke")
ax4=fig.add_subplot(gs[4:7,0:3],facecolor="whitesmoke")
ax5=fig.add_subplot(gs[4:7,4:7],facecolor="whitesmoke")
ax6=fig.add_subplot(gs[4:7,8:11],facecolor="whitesmoke")
ax7=fig.add_subplot(gs[8:11,0:3],facecolor="whitesmoke")
ax8=fig.add_subplot(gs[8:11,4:7],facecolor="whitesmoke")
ax9=fig.add_subplot(gs[8:11,8:11],facecolor="whitesmoke")
font1={'family': 'Times New Roman', 'weight': 'light', 'size': 12}#设置字体模板，
#金徽酒
sns.heatmap(jin_cor,linewidths=0.05,ax=ax1,vmax=1,vmin=-1,cmap="rainbow")
ax1.set_title("Jinhui Liquor Co., Ltd(603919)",fontsize=10)
#ax1.set_xlabel('')
ax1.set_xlabel('Technical Indicators',fontsize=12)
ax1.set_ylabel("Technical Indicators",fontsize=12)
#今世缘
sns.heatmap(jinshiyuan_cor,linewidths=0.05,ax=ax2,vmax=1,vmin=-1,cmap="rainbow")
ax2.set_title("King's Luck Brewery Joint-Stock Co., Ltd(603369)",fontsize=10)
ax2.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax2.set_ylabel("Technical Indicators",fontsize=12)

#老白干酒
sns.heatmap(laobai_cor,linewidths=0.05,ax=ax3,vmax=1,vmin=-1,cmap="rainbow")
ax3.set_title("Laobaigan Liquor Co., Ltd(600559)",fontsize=10)
ax3.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax3.set_ylabel("Technical Indicators",fontsize=12)
#维维
sns.heatmap(weiwei_cor,linewidths=0.05,ax=ax4,vmax=1,vmin=-1,cmap="rainbow")
ax4.set_title(r"V V Food & Beverage Co., Ltd(600300)",fontsize=10)
ax4.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax4.set_ylabel("Technical Indicators",fontsize=12)

#同仁
sns.heatmap(tongren_cor,linewidths=0.05,ax=ax5,vmax=1,vmin=-1,cmap="rainbow")
ax5.set_title(r"Beijing Tongrentang Co.,ltd. (600085)",fontsize=10)
ax5.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax5.set_ylabel("Technical Indicators",fontsize=12)
#贵州
sns.heatmap(guizhou_cor,linewidths=0.05,ax=ax6,vmax=1,vmin=-1,cmap="rainbow")
ax6.set_title(r"Kweichow Moutai Co.,Ltd. (600519)",fontsize=10)
ax6.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax6.set_ylabel("Technical Indicators",fontsize=12)
# 白云山
sns.heatmap(baiyunshan_cor,linewidths=0.05,ax=ax7,vmax=1,vmin=-1,cmap="rainbow")
ax7.set_title(r"Guangzhou Baiyunshan Pharmaceutical Holdings Company Limited (600332)",fontsize=10)
ax7.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax7.set_ylabel("Technical Indicators",fontsize=12)
# 洋河
sns.heatmap(yanghe_cor,linewidths=0.05,ax=ax8,vmax=1,vmin=-1,cmap="rainbow")
ax8.set_title(r"JIANGSU YANGHE DISTILLERY CO., LTD. (002304)",fontsize=10)
ax8.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax8.set_ylabel("Technical Indicators",fontsize=12)
# 山西
sns.heatmap(shanxi_cor,linewidths=0.05,ax=ax9,vmax=1,vmin=-1,cmap="rainbow")
ax9.set_title(r"Shanxi Xinghuacun Fen Wine Factory Co.,Ltd. (600809)",fontsize=10)
ax9.set_xlabel('Technical Indicators',fontsize=12)
#ax2.set_xticklabels([]) #设置x轴图例为空值
ax9.set_ylabel("Technical Indicators",fontsize=12)
plt.savefig("correlation.eps",format="eps",dpi=100, bbox_inches='tight')
