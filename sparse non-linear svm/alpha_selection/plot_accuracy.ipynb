# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import matplotlib.ticker
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

#% matplotlib inline
font1={'family': 'Times New Roman', 'weight': 'light', 'size':17}#设置字体模板
font2={'family': 'Times New Roman', 'weight': 'bold', 'size': 16}#设置字体模板
fig = plt.figure(figsize=(20,20),facecolor="snow")
#fig.suptitle("Controlling spacing around and between subplots")

gs=GridSpec(12,12)
ax1=fig.add_subplot(gs[0:3, 0:3],facecolor="whitesmoke")
ax2=fig.add_subplot(gs[0:3, 4:7],facecolor="whitesmoke")
ax3=fig.add_subplot(gs[0:3,8:11],facecolor="whitesmoke")
ax4=fig.add_subplot(gs[4:7,0:3],facecolor="whitesmoke")
ax5=fig.add_subplot(gs[4:7,4:7],facecolor="whitesmoke")
ax6=fig.add_subplot(gs[4:7,8:11],facecolor="whitesmoke")
ax7=fig.add_subplot(gs[8:11,0:3],facecolor="whitesmoke")
ax8=fig.add_subplot(gs[8:11,4:7],facecolor="whitesmoke")
ax9=fig.add_subplot(gs[8:11,8:11],facecolor="whitesmoke")

jinhui=np.array(pd.read_csv("jinhui_accuracy.csv"))[:,1:]
jinshi=np.array(pd.read_csv("jinshi_accuracy.csv"))[:,1:]
laobai=np.array(pd.read_csv("laobai_accuracy.csv"))[:,1:]
weiwei=np.array(pd.read_csv("weiwei_accuracy.csv"))[:,1:]
yanghe=np.array(pd.read_csv("yanghe_accuracy.csv"))[:,1:]
tongren=np.array(pd.read_csv("tongren_accuracy.csv"))[:,1:]
shanxi=np.array(pd.read_csv("shanxi_accuracy.csv"))[:,1:]
baiyun=np.array(pd.read_csv("baiyun_accuracy.csv"))[:,1:]
guizhou=np.array(pd.read_csv("guizhou_accuracy.csv"))[:,1:]

feature_num=[i for i in range(1,50)]
#金徽
jinhui_prop_1=jinhui[0]
jinhui_prop_2=jinhui[1]
jinhui_prop_3=jinhui[2]
jinhui_prop_4=jinhui[3]
jinhui_prop_5=jinhui[4]
jinhui_prop_6=jinhui[5]
jinhui_prop_7=jinhui[6]
jinhui_prop_8=jinhui[7]
jinhui_prop_9=jinhui[8]
jinhui_RFE_SVM=jinhui[9]
jinhui_ReliefF_SVM=jinhui[10]
ax1.plot(feature_num, jinhui_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax1.plot(feature_num, jinhui_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax1.plot(feature_num, jinhui_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax1.plot(feature_num, jinhui_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax1.plot(feature_num, jinhui_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax1.plot(feature_num, jinhui_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax1.plot(feature_num, jinhui_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax1.plot(feature_num, jinhui_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax1.plot(feature_num, jinhui_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax1.plot(feature_num, jinhui_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax1.plot(feature_num, jinhui_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)

ax1.set_xlabel('')
#ax1.set_xticklabels([])
ax1.set_xlabel("Feature Number",fontsize=15)
ax1.set_title("Jinhui Liquor Co., Ltd(603919)",fontsize=9)
ax1.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax1.xaxis.grid(True, which='major')
ax1.yaxis.grid(True, which='major')
ax1.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
#ax1.legend(bbox_to_anchor=(4,-3),scatterpoints=1,prop=font1,shadow=True,frameon=False,ncol=5)#添加图例，
ax1.ticklabel_format(axis='both',style='sci')#sci文章的风格
ax1.tick_params(labelsize=15)


#今世
jinshi_prop_1=jinshi[0]
jinshi_prop_2=jinshi[1]
jinshi_prop_3=jinshi[2]
jinshi_prop_4=jinshi[3]
jinshi_prop_5=jinshi[4]
jinshi_prop_6=jinshi[5]
jinshi_prop_7=jinshi[6]
jinshi_prop_8=jinshi[7]
jinshi_prop_9=jinshi[8]
jinshi_RFE_SVM=jinshi[9]
jinshi_ReliefF_SVM=jinshi[10]

ax2.plot(feature_num, jinshi_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax2.plot(feature_num, jinshi_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax2.plot(feature_num, jinshi_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax2.plot(feature_num, jinshi_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax2.plot(feature_num, jinshi_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax2.plot(feature_num, jinshi_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax2.plot(feature_num, jinshi_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax2.plot(feature_num, jinshi_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax2.plot(feature_num, jinshi_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax2.plot(feature_num, jinshi_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax2.plot(feature_num, jinshi_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)

ax2.set_xlabel('')
#ax1.set_xticklabels([])
ax2.set_xlabel("Feature Number",fontsize=15)
ax2.set_title("King's Luck Brewery Joint-Stock Co., Ltd(603369)",fontsize=9)
ax2.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax2.xaxis.grid(True, which='major')
ax2.yaxis.grid(True, which='major')
ax2.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax2.ticklabel_format(axis='both',style='sci')#sci文章的风格
ax2.tick_params(labelsize=15)

#老白
laobai_prop_1=laobai[0]
laobai_prop_2=laobai[1]
laobai_prop_3=laobai[2]
laobai_prop_4=laobai[3]
laobai_prop_5=laobai[4]
laobai_prop_6=laobai[5]
laobai_prop_7=laobai[6]
laobai_prop_8=laobai[7]
laobai_prop_9=laobai[8]
laobai_RFE_SVM=laobai[9]
laobai_ReliefF_SVM=laobai[10]


ax3.plot(feature_num, laobai_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax3.plot(feature_num, laobai_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax3.plot(feature_num, laobai_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax3.plot(feature_num, laobai_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax3.plot(feature_num, laobai_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax3.plot(feature_num, laobai_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax3.plot(feature_num, laobai_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax3.plot(feature_num, laobai_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax3.plot(feature_num, laobai_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax3.plot(feature_num, laobai_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax3.plot(feature_num, laobai_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)



ax3.set_xlabel('')
#ax1.set_xticklabels([])
ax3.set_xlabel("Feature Number",fontsize=15)
ax3.set_title("Laobaigan Liquor Co., Ltd(600559)",fontsize=9)
ax3.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax3.xaxis.grid(True, which='major')
ax3.yaxis.grid(True, which='major')
ax3.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax3.ticklabel_format(axis='both',style='sci')#sci文章的风格
ax3.tick_params(labelsize=15)

#维维
weiwei_prop_1=weiwei[0]
weiwei_prop_2=weiwei[1]
weiwei_prop_3=weiwei[2]
weiwei_prop_4=weiwei[3]
weiwei_prop_5=weiwei[4]
weiwei_prop_6=weiwei[5]
weiwei_prop_7=weiwei[6]
weiwei_prop_8=weiwei[7]
weiwei_prop_9=weiwei[8]
weiwei_RFE_SVM=weiwei[9]
weiwei_ReliefF_SVM=weiwei[10]
ax4.plot(feature_num, weiwei_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax4.plot(feature_num, weiwei_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax4.plot(feature_num, weiwei_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax4.plot(feature_num, weiwei_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax4.plot(feature_num, weiwei_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax4.plot(feature_num, weiwei_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax4.plot(feature_num, weiwei_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax4.plot(feature_num, weiwei_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax4.plot(feature_num, weiwei_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax4.plot(feature_num,weiwei_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax4.plot(feature_num, weiwei_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)


ax4.set_xlabel('')
#ax1.set_xticklabels([])
ax4.set_xlabel("Feature Number",fontsize=15)
ax4.set_title("V V Food & Beverage Co., Ltd(600300)",fontsize=9)
ax4.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax4.xaxis.grid(True, which='major')
ax4.yaxis.grid(True, which='major')
ax4.tick_params(labelsize=15)
ax4.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax4.ticklabel_format(axis='both',style='sci')#sci文章的风格

#贵州
guizhou_prop_1=guizhou[0]
guizhou_prop_2=guizhou[1]
guizhou_prop_3=guizhou[2]
guizhou_prop_4=guizhou[3]
guizhou_prop_5=guizhou[4]
guizhou_prop_6=guizhou[5]
guizhou_prop_7=guizhou[6]
guizhou_prop_8=guizhou[7]
guizhou_prop_9=guizhou[8]
guizhou_RFE_SVM=guizhou[9]
guizhou_ReliefF_SVM=guizhou[10]
ax5.plot(feature_num, guizhou_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax5.plot(feature_num, guizhou_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax5.plot(feature_num, guizhou_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax5.plot(feature_num, guizhou_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax5.plot(feature_num, guizhou_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax5.plot(feature_num, guizhou_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax5.plot(feature_num, guizhou_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax5.plot(feature_num, guizhou_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax5.plot(feature_num, guizhou_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax5.plot(feature_num,guizhou_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax5.plot(feature_num, guizhou_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)


ax5.set_xlabel('')
#ax1.set_xticklabels([])
ax5.set_xlabel("Feature Number",fontsize=15)
ax5.set_title("Kweichow Moutai Co.,Ltd. (600519)",fontsize=9)
ax5.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax5.xaxis.grid(True, which='major')
ax5.yaxis.grid(True, which='major')
ax5.tick_params(labelsize=15)
ax5.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax5.ticklabel_format(axis='both',style='sci')#sci文章的风格

#山西
shanxi_prop_1=shanxi[0]
shanxi_prop_2=shanxi[1]
shanxi_prop_3=shanxi[2]
shanxi_prop_4=shanxi[3]
shanxi_prop_5=shanxi[4]
shanxi_prop_6=shanxi[5]
shanxi_prop_7=shanxi[6]
shanxi_prop_8=shanxi[7]
shanxi_prop_9=shanxi[8]
shanxi_RFE_SVM=shanxi[9]
shanxi_ReliefF_SVM=shanxi[10]
ax6.plot(feature_num, shanxi_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax6.plot(feature_num, shanxi_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax6.plot(feature_num, shanxi_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax6.plot(feature_num, shanxi_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax6.plot(feature_num, shanxi_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax6.plot(feature_num, shanxi_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax6.plot(feature_num, shanxi_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax6.plot(feature_num, shanxi_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax6.plot(feature_num, shanxi_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax6.plot(feature_num, shanxi_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax6.plot(feature_num, shanxi_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)


ax6.set_xlabel('')
#ax1.set_xticklabels([])
ax6.set_xlabel("Feature Number",fontsize=15)
ax6.set_title("Shanxi Xinghuacun Fen Wine Factory Co.,Ltd. (600809)",fontsize=9)
ax6.set_ylabel('Average Accuracy',fontsize=9)
#ax1.set_xticks(feature_num)
ax6.xaxis.grid(True, which='major')
ax6.yaxis.grid(True, which='major')
ax6.tick_params(labelsize=15)
ax6.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax6.ticklabel_format(axis='both',style='sci')#sci文章的风格

#同仁
tongren_prop_1=tongren[0]
tongren_prop_2=tongren[1]
tongren_prop_3=tongren[2]
tongren_prop_4=tongren[3]
tongren_prop_5=tongren[4]
tongren_prop_6=tongren[5]
tongren_prop_7=tongren[6]
tongren_prop_8=tongren[7]
tongren_prop_9=tongren[8]
tongren_RFE_SVM=tongren[9]
tongren_ReliefF_SVM=tongren[10]
ax7.plot(feature_num, tongren_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax7.plot(feature_num, tongren_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax7.plot(feature_num, tongren_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax7.plot(feature_num, tongren_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax7.plot(feature_num, tongren_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax7.plot(feature_num, tongren_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax7.plot(feature_num, tongren_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax7.plot(feature_num, tongren_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax7.plot(feature_num, tongren_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax7.plot(feature_num, tongren_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax7.plot(feature_num, tongren_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)


ax7.set_xlabel('')
#ax1.set_xticklabels([])
ax7.set_xlabel("Feature Number",fontsize=15)
ax7.set_title("Beijing Tongrentang Co.,ltd. (600085)",fontsize=9)
ax7.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax7.xaxis.grid(True, which='major')
ax7.yaxis.grid(True, which='major')
ax7.tick_params(labelsize=15)
ax7.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax7.ticklabel_format(axis='both',style='sci')#sci文章的风格

#洋河
yanghe_prop_1=yanghe[0]
yanghe_prop_2=yanghe[1]
yanghe_prop_3=yanghe[2]
yanghe_prop_4=yanghe[3]
yanghe_prop_5=yanghe[4]
yanghe_prop_6=yanghe[5]
yanghe_prop_7=yanghe[6]
yanghe_prop_8=yanghe[7]
yanghe_prop_9=yanghe[8]
yanghe_RFE_SVM=yanghe[9]
yanghe_ReliefF_SVM=yanghe[10]
ax8.plot(feature_num, yanghe_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax8.plot(feature_num, yanghe_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax8.plot(feature_num, yanghe_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax8.plot(feature_num, yanghe_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax8.plot(feature_num, yanghe_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax8.plot(feature_num, yanghe_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax8.plot(feature_num, yanghe_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax8.plot(feature_num, yanghe_prop_8, "|-", color="peru", label=r"Proposed Method with  $\alpha$=0.85", lw=1.5)
ax8.plot(feature_num, yanghe_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax8.plot(feature_num, yanghe_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax8.plot(feature_num, yanghe_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)


ax8.set_xlabel('')
#ax1.set_xticklabels([])
ax8.set_xlabel("Feature Number",fontsize=15)
ax8.set_title("JIANGSU YANGHE DISTILLERY CO., LTD. (002304)",fontsize=9)
ax8.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax8.xaxis.grid(True, which='major')
ax8.yaxis.grid(True, which='major')
ax8.tick_params(labelsize=15)
ax8.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax8.ticklabel_format(axis='both',style='sci')#sci文章的风格

#白云
baiyun_prop_1=baiyun[0]
baiyun_prop_2=baiyun[1]
baiyun_prop_3=baiyun[2]
baiyun_prop_4=baiyun[3]
baiyun_prop_5=baiyun[4]
baiyun_prop_6=baiyun[5]
baiyun_prop_7=baiyun[6]
baiyun_prop_8=baiyun[7]
baiyun_prop_9=baiyun[8]
baiyun_RFE_SVM=baiyun[9]
baiyun_ReliefF_SVM=baiyun[10]
ax9.plot(feature_num, baiyun_prop_1, "h-", color="skyblue", label=r"Proposed Method with $\alpha$=0.15", lw=1.5)
ax9.plot(feature_num, baiyun_prop_2, "v-", color="green", label=r"Proposed Method with $\alpha$=0.25", lw=1.5)
ax9.plot(feature_num, baiyun_prop_3, "x-", color="gray", label=r"Proposed Method with $\alpha$=0.35", lw=1.5)
ax9.plot(feature_num, baiyun_prop_4, "P-", color="cyan", label=r"Proposed Method with $\alpha$=0.45", lw=1.5)
ax9.plot(feature_num, baiyun_prop_5, "*-", color="magenta", label=r"Proposed Method with $\alpha$=0.55", lw=1.5)
ax9.plot(feature_num, baiyun_prop_6, "1-", color="yellow", label=r"Proposed Method with $\alpha$=0.65", lw=1.5)
ax9.plot(feature_num, baiyun_prop_7, "^-", color="pink", label=r"Proposed Method with $\alpha$=0.75", lw=1.5)
ax9.plot(feature_num, baiyun_prop_8, "|-", color="peru", label=r"Proposed Method with $\alpha$=0.85", lw=1.5)
ax9.plot(feature_num, baiyun_prop_9, "--", color="blue", label=r"Proposed Method with $\alpha$=0.95", lw=1.5)
ax9.plot(feature_num, baiyun_RFE_SVM, "-", color="black", label=r"SVMs-RFE", lw=1.5)
ax9.plot(feature_num, baiyun_ReliefF_SVM, "--", color="red", label=r"ReliefF-based SVMs", lw=1.5)


ax9.set_xlabel('')
#ax1.set_xticklabels([])+-9
ax9.set_xlabel("Feature Number",fontsize=15)
ax9.set_title("Guangzhou Baiyunshan Pharmaceutical Holdings Company Limited (600332)",fontsize=9)
ax9.set_ylabel('Average Accuracy',fontsize=15)
#ax1.set_xticks(feature_num)
ax9.xaxis.grid(True, which='major')
ax9.yaxis.grid(True, which='major')
ax9.tick_params(labelsize=15)
ax9.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(4))
ax9.ticklabel_format(axis='both',style='sci')#sci文章的风格
#plt.savefig("accuracy_linear.eps",format='eps',dpi=1000, bbox_inches='tight')
ax1.legend(bbox_to_anchor=(4.55,-3),scatterpoints=1,prop=font1,shadow=True,frameon=False,ncol=5)#添加图例，
plt.savefig("accuracy_nonlinear.eps",format='eps',dpi=1000, bbox_inches='tight')
